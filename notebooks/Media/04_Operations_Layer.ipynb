# %% [markdown]
# # Getting Started
#
# ML Ops is gaining a lot of popularity. This example showcases a key piece you can use to construct your automation pipeline. As we can see in the following architecture diagram, you will be deploying an AWS Step Funciton Workflow containing AWS Lambda functions that call Amazon S3, Amazon Personalize, and Amazon SNS APIs.
#
#
# This package contains the source code of a Step Functions pipeline that is able to perform
# multiple actions within **Amazon Personalize**, including the following:
#
# - Dataset Group creation
# - Datasets creation and import
# - Solution creation
# - Solution version creation
# - Campaign creation
#
# Once the steps are completed, the step functions notifies the users of its completion through the
# use of an SNS topic.
#
# The below diagram describes the architecture of the solution:
#
# ![Architecture Diagram](../../static/imgs/ml_ops_architecture.png)
#
# The below diagram showcases the StepFunction workflow definition:
#
# ![stepfunction definition](../../static/imgs/step_functions.png)

# %% [markdown]
# ## Prerequisites
#
# ### Installing AWS SAM
#
# The AWS Serverless Application Model (SAM) is an open-source framework for building serverless applications. It provides shorthand syntax to express functions, APIs, databases, and event source mappings. With just a few lines per resource, you can define the application you want and model it using YAML. During deployment, SAM transforms and expands the SAM syntax into AWS CloudFormation syntax, enabling you to build serverless applications faster.
#
# **Install** the [AWS SAM CLI](https://docs.aws.amazon.com/serverless-application-model/latest/developerguide/serverless-sam-cli-install.html).
# This will install the necessary tools to build, deploy, and locally test your project. In this particular example we will be using AWS SAM to build and deploy only. For additional information please visit our [documentation](https://docs.aws.amazon.com/serverless-application-model/latest/developerguide/what-is-sam.html).
#
#
# **Note:** We have pre-installed SAM CLI in this notebooks through a cloudformation life cycle policy config
#
# Let's check what version of SAM we have installed

# %%
# !sam --version
# Out:
# SAM CLI, version 1.18.2

# %% [markdown]
# ## Directory Structure
#
# Let's take a look at directory structure.

# %% [markdown]
# We have a couple artifacts that we will be using to build our MLOps pipeline.

# %%
# !ls /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops
# Out:
# deploy.sh  domain  lambdas  LICENSE  shared  template.yaml

# %% [markdown]
# **`ml_ops/domain`**
# * This directory contains the configuration file and sample data based on the domain. In this example we are going to be using the Media domain

# %%
# !ls /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops/domain
# Out:
# CPG  Media  Retail

# %% [markdown]
# **`ml_ops/lambdas`**
# * This directory contains all the code that will be going into the lambda functions, these lambda functions will become a step inside the stepfunctions state machine we will deploy

# %%
# !ls /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops/lambdas
# Out:
# create-campaign      event-tracker	     s3lambda
# create-dataset	     import-data	     wait-delete-campaign
# create-datasetgroup  list-campaigns	     wait-delete-dataset
# create-solution      list-datasets	     wait-delete-datasetgroup
# delete-campaign      list-solutions	     wait-delete-solution
# delete-dataset	     list-solution-versions  wait-delete-tracker
# delete-datasetgroup  list-trackers	     wait-solution-version
# delete-solution      notify
# delete-tracker	     notify-delete

# %% [markdown]
# **`ml_ops/template.yaml`**
# * This is our SAM template that will deploy the automation into our account, here we are printing just the head

# %%
# !head /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops/template.yaml
# Out:
# AWSTemplateFormatVersion: '2010-09-09'
# Transform: AWS::Serverless-2016-10-31
# Description: >
#
# Globals:
#   Function:
#     Timeout: 300
#
# Resources:

# %% [markdown]
# ## Deploying
#
# In order to deploy the project you will need to run the following commands:

# %%
# !cd /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops/; sam build
# Out:
# Building codeuri: lambdas/s3lambda/ runtime: python3.7 metadata: {} functions: ['S3Lambda']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/notify/ runtime: python3.7 metadata: {} functions: ['Notify']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/notify-delete/ runtime: python3.7 metadata: {} functions: ['NotifyDelete']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/create-datasetgroup/ runtime: python3.7 metadata: {} functions: ['CreateDatasetGroup']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/create-dataset/ runtime: python3.7 metadata: {} functions: ['CreateDataset']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/import-data/ runtime: python3.7 metadata: {} functions: ['ImportData']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/create-solution/ runtime: python3.7 metadata: {} functions: ['CreateSolution']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/wait-solution-version runtime: python3.7 metadata: {} functions: ['WaitSolutionVersion']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/create-campaign/ runtime: python3.7 metadata: {} functions: ['CreateCampaign']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/delete-campaign/ runtime: python3.7 metadata: {} functions: ['DeleteCampaign']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/delete-dataset/ runtime: python3.7 metadata: {} functions: ['DeleteDataset']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/delete-datasetgroup/ runtime: python3.7 metadata: {} functions: ['DeleteDatasetGroup']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/delete-solution runtime: python3.7 metadata: {} functions: ['DeleteSolution']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/delete-tracker runtime: python3.7 metadata: {} functions: ['DeleteTracker']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/list-campaigns runtime: python3.7 metadata: {} functions: ['ListCampaigns']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/list-datasets runtime: python3.7 metadata: {} functions: ['ListDatasets']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/list-solution-versions runtime: python3.7 metadata: {} functions: ['ListSolutionVersions']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/list-solutions runtime: python3.7 metadata: {} functions: ['ListSolutions']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/list-trackers runtime: python3.7 metadata: {} functions: ['ListTrackers']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/wait-delete-campaign runtime: python3.7 metadata: {} functions: ['WaitDeleteCampaign']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/wait-delete-dataset runtime: python3.7 metadata: {} functions: ['WaitDeleteDataset']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/wait-delete-datasetgroup runtime: python3.7 metadata: {} functions: ['WaitDeleteDatasetgroup']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/wait-delete-solution runtime: python3.7 metadata: {} functions: ['WaitDeleteSolution']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/wait-delete-tracker runtime: python3.7 metadata: {} functions: ['WaitDeleteTracker']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
# Building codeuri: lambdas/event-tracker/ runtime: python3.7 metadata: {} functions: ['AttachEventTracker']
# Running PythonPipBuilder:ResolveDependencies
# Running PythonPipBuilder:CopySource
#
# Build Succeeded
#
# Built Artifacts  : .aws-sam/build
# Built Template   : .aws-sam/build/template.yaml
#
# Commands you can use next
# =========================
# [*] Invoke Function: sam local invoke
# [*] Deploy: sam deploy --guided
#
#
# SAM CLI update available (1.19.1); (1.18.2 installed)
# To download: https://docs.aws.amazon.com/serverless-application-model/latest/developerguide/serverless-sam-cli-install.html

# %%
# !cd /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops/; sam deploy --template-file template.yaml --stack-name notebook-automation --capabilities CAPABILITY_IAM --s3-bucket $(aws cloudformation describe-stack-resources --stack-name AmazonPersonalizeImmersionDay --logical-resource-id SAMArtifactsBucket --query "StackResources[0].PhysicalResourceId" --output text)
# Out:
# 	Deploying with following values
# 	===============================
# 	Stack name                   : notebook-automation
# 	Region                       : us-east-1
# 	Confirm changeset            : False
# 	Deployment s3 bucket         : amazonpersonalizeimmersionday-samartifactsbucket-1v39jxpau3gqg
# 	Capabilities                 : ["CAPABILITY_IAM"]
# 	Parameter overrides          : {}
# 	Signing Profiles             : {}
#
# Initiating deployment
# =====================
#
# Waiting for changeset to be created..
#
# CloudFormation stack changeset
# -------------------------------------------------------------------------------------------------
# Operation                LogicalResourceId        ResourceType             Replacement
# -------------------------------------------------------------------------------------------------
# + Add                    AttachEventTrackerRole   AWS::IAM::Role           N/A
# + Add                    AttachEventTracker       AWS::Lambda::Function    N/A
# + Add                    CreateCampaignRole       AWS::IAM::Role           N/A
# + Add                    CreateCampaign           AWS::Lambda::Function    N/A
# + Add                    CreateDatasetGroupRole   AWS::IAM::Role           N/A
# + Add                    CreateDatasetGroup       AWS::Lambda::Function    N/A
# + Add                    CreateDatasetRole        AWS::IAM::Role           N/A
# + Add                    CreateDataset            AWS::Lambda::Function    N/A
# + Add                    CreateSolutionRole       AWS::IAM::Role           N/A
# + Add                    CreateSolution           AWS::Lambda::Function    N/A
# + Add                    DeleteAllDatasetGroupR   AWS::StepFunctions::St   N/A
#                          esources                 ateMachine
# + Add                    DeleteCampaignRole       AWS::IAM::Role           N/A
# + Add                    DeleteCampaign           AWS::Lambda::Function    N/A
# + Add                    DeleteDatasetGroupRole   AWS::IAM::Role           N/A
# + Add                    DeleteDatasetGroup       AWS::Lambda::Function    N/A
# + Add                    DeleteDatasetRole        AWS::IAM::Role           N/A
# + Add                    DeleteDataset            AWS::Lambda::Function    N/A
# + Add                    DeleteSolutionRole       AWS::IAM::Role           N/A
# + Add                    DeleteSolution           AWS::Lambda::Function    N/A
# + Add                    DeleteTrackerRole        AWS::IAM::Role           N/A
# + Add                    DeleteTracker            AWS::Lambda::Function    N/A
# + Add                    DeployStateMachine       AWS::StepFunctions::St   N/A
#                                                   ateMachine
# + Add                    ImportDataRole           AWS::IAM::Role           N/A
# + Add                    ImportData               AWS::Lambda::Function    N/A
# + Add                    InputBucket              AWS::S3::Bucket          N/A
# + Add                    ListCampaignsRole        AWS::IAM::Role           N/A
# + Add                    ListCampaigns            AWS::Lambda::Function    N/A
# + Add                    ListDatasetsRole         AWS::IAM::Role           N/A
# + Add                    ListDatasets             AWS::Lambda::Function    N/A
# + Add                    ListSolutionVersionsRo   AWS::IAM::Role           N/A
#                          le
# + Add                    ListSolutionVersions     AWS::Lambda::Function    N/A
# + Add                    ListSolutionsRole        AWS::IAM::Role           N/A
# + Add                    ListSolutions            AWS::Lambda::Function    N/A
# + Add                    ListTrackersRole         AWS::IAM::Role           N/A
# + Add                    ListTrackers             AWS::Lambda::Function    N/A
# + Add                    NotifyDeleteRole         AWS::IAM::Role           N/A
# + Add                    NotifyDelete             AWS::Lambda::Function    N/A
# + Add                    NotifyRole               AWS::IAM::Role           N/A
# + Add                    Notify                   AWS::Lambda::Function    N/A
# + Add                    PersonalizeRole          AWS::IAM::Role           N/A
# + Add                    PersonalizeS3Policy      AWS::S3::BucketPolicy    N/A
# + Add                    S3LambdaS3BucketPermis   AWS::Lambda::Permissio   N/A
#                          sion                     n
# + Add                    S3Lambda                 AWS::Lambda::Function    N/A
# + Add                    SharedLayere7d800bdcd    AWS::Lambda::LayerVers   N/A
#                                                   ion
# + Add                    StatesExecutionRole      AWS::IAM::Role           N/A
# + Add                    TriggerRole              AWS::IAM::Role           N/A
# + Add                    WaitDeleteCampaignRole   AWS::IAM::Role           N/A
# + Add                    WaitDeleteCampaign       AWS::Lambda::Function    N/A
# + Add                    WaitDeleteDatasetRole    AWS::IAM::Role           N/A
# + Add                    WaitDeleteDatasetgroup   AWS::IAM::Role           N/A
#                          Role
# + Add                    WaitDeleteDatasetgroup   AWS::Lambda::Function    N/A
# + Add                    WaitDeleteDataset        AWS::Lambda::Function    N/A
# + Add                    WaitDeleteSolutionRole   AWS::IAM::Role           N/A
# + Add                    WaitDeleteSolution       AWS::Lambda::Function    N/A
# + Add                    WaitDeleteTrackerRole    AWS::IAM::Role           N/A
# + Add                    WaitDeleteTracker        AWS::Lambda::Function    N/A
# + Add                    WaitSolutionVersionRol   AWS::IAM::Role           N/A
#                          e
# + Add                    WaitSolutionVersion      AWS::Lambda::Function    N/A
# -------------------------------------------------------------------------------------------------
#
# Changeset created successfully. arn:aws:cloudformation:us-east-1:144386903708:changeSet/samcli-deploy1614874634/f3074321-e49e-4ccd-849e-bc4c9b976088
#
#
# 2021-03-04 16:17:35 - Waiting for stack create/update to complete
#
# CloudFormation events from changeset
# -------------------------------------------------------------------------------------------------
# ResourceStatus           ResourceType             LogicalResourceId        ResourceStatusReason
# -------------------------------------------------------------------------------------------------
# CREATE_IN_PROGRESS       AWS::IAM::Role           StatesExecutionRole      -
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteDatasetRole    -
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitSolutionVersionRol   -
#                                                   e
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteSolutionRole   -
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateDatasetRole        -
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListSolutionVersionsRo   Resource creation
#                                                   le                       Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteTrackerRole    Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteDatasetRole        Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListDatasetsRole         Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           NotifyRole               -
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListTrackersRole         Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteDatasetgroup   Resource creation
#                                                   Role                     Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListSolutionsRole        Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListCampaignsRole        Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteCampaignRole   -
# CREATE_IN_PROGRESS       AWS::Lambda::LayerVers   SharedLayere7d800bdcd    -
#                          ion
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateDatasetGroupRole   Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteSolutionRole       -
# CREATE_IN_PROGRESS       AWS::IAM::Role           NotifyDeleteRole         -
# CREATE_IN_PROGRESS       AWS::IAM::Role           StatesExecutionRole      Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateSolutionRole       -
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteTrackerRole    -
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListSolutionVersionsRo   -
#                                                   le
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListDatasetsRole         -
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteDatasetgroup   -
#                                                   Role
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteDatasetRole        -
# CREATE_IN_PROGRESS       AWS::IAM::Role           AttachEventTrackerRole   -
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListSolutionsRole        -
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteCampaignRole       -
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListTrackersRole         -
# CREATE_IN_PROGRESS       AWS::IAM::Role           TriggerRole              -
# CREATE_IN_PROGRESS       AWS::IAM::Role           PersonalizeRole          -
# CREATE_IN_PROGRESS       AWS::IAM::Role           ListCampaignsRole        -
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteDatasetGroupRole   -
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateDatasetGroupRole   -
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteTrackerRole        -
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateCampaignRole       -
# CREATE_IN_PROGRESS       AWS::IAM::Role           NotifyDeleteRole         Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteDatasetRole    Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteSolutionRole   Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           TriggerRole              Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateDatasetRole        Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteDatasetGroupRole   Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::LayerVers   SharedLayere7d800bdcd    -
#                          ion
# CREATE_IN_PROGRESS       AWS::Lambda::LayerVers   SharedLayere7d800bdcd    Resource creation
#                          ion                                               Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteCampaignRole       Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           WaitDeleteCampaignRole   Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           PersonalizeRole          Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           StatesExecutionRole      -
# CREATE_COMPLETE          AWS::IAM::Role           ListSolutionsRole        -
# CREATE_COMPLETE          AWS::IAM::Role           ListCampaignsRole        -
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteTrackerRole        Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           WaitDeleteDatasetgroup   -
#                                                   Role
# CREATE_IN_PROGRESS       AWS::IAM::Role           NotifyRole               Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateCampaignRole       Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteDatasetgroup   -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListCampaigns            -
# CREATE_COMPLETE          AWS::IAM::Role           CreateDatasetGroupRole   -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListSolutions            -
# CREATE_COMPLETE          AWS::IAM::Role           ListDatasetsRole         -
# CREATE_COMPLETE          AWS::IAM::Role           WaitDeleteSolutionRole   -
# CREATE_IN_PROGRESS       AWS::IAM::Role           CreateSolutionRole       Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           ListSolutionVersionsRo   -
#                                                   le
# CREATE_COMPLETE          AWS::IAM::Role           DeleteDatasetGroupRole   -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteDatasetgroup   Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           WaitDeleteDatasetRole    -
# CREATE_IN_PROGRESS       AWS::IAM::Role           DeleteSolutionRole       Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    WaitDeleteDatasetgroup   -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListCampaigns            Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListSolutions            Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           CreateDatasetRole        -
# CREATE_COMPLETE          AWS::Lambda::Function    ListCampaigns            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListSolutionVersions     -
# CREATE_COMPLETE          AWS::IAM::Role           DeleteDatasetRole        -
# CREATE_COMPLETE          AWS::Lambda::Function    ListSolutions            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteDataset        -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateDatasetGroup       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListDatasets             -
# CREATE_COMPLETE          AWS::IAM::Role           NotifyDeleteRole         -
# CREATE_COMPLETE          AWS::IAM::Role           ListTrackersRole         -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteSolution       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteDatasetGroup       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateDataset            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteSolution       Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteDataset        Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteDataset            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateDataset            Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    NotifyDelete             -
# CREATE_COMPLETE          AWS::Lambda::Function    WaitDeleteSolution       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListTrackers             -
# CREATE_COMPLETE          AWS::Lambda::Function    WaitDeleteDataset        -
# CREATE_COMPLETE          AWS::IAM::Role           WaitDeleteCampaignRole   -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteTracker        -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateDatasetGroup       Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    CreateDataset            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    NotifyDelete             Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListSolutionVersions     Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    CreateDatasetGroup       -
# CREATE_COMPLETE          AWS::IAM::Role           DeleteCampaignRole       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListDatasets             Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    ListSolutionVersions     -
# CREATE_COMPLETE          AWS::Lambda::Function    NotifyDelete             -
# CREATE_COMPLETE          AWS::IAM::Role           PersonalizeRole          -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteDatasetGroup       Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    ListDatasets             -
# CREATE_COMPLETE          AWS::Lambda::Function    DeleteDatasetGroup       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteCampaign           -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteCampaign       -
# CREATE_COMPLETE          AWS::Lambda::Function    DeleteDataset            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteTracker        Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ListTrackers             Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           ImportDataRole           Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    WaitDeleteTracker        -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitDeleteCampaign       Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::IAM::Role           ImportDataRole           -
# CREATE_COMPLETE          AWS::Lambda::Function    ListTrackers             -
# CREATE_COMPLETE          AWS::Lambda::Function    WaitDeleteCampaign       -
# CREATE_IN_PROGRESS       AWS::IAM::Role           AttachEventTrackerRole   Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           DeleteTrackerRole        -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteCampaign           Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    DeleteCampaign           -
# CREATE_COMPLETE          AWS::IAM::Role           NotifyRole               -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteTracker            -
# CREATE_COMPLETE          AWS::IAM::Role           CreateCampaignRole       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    Notify                   -
# CREATE_COMPLETE          AWS::Lambda::Function    Notify                   -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateCampaign           -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    Notify                   Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           CreateSolutionRole       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteTracker            Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::IAM::Role           DeleteSolutionRole       -
# CREATE_COMPLETE          AWS::IAM::Role           WaitSolutionVersionRol   -
#                                                   e
# CREATE_COMPLETE          AWS::Lambda::Function    DeleteTracker            -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateCampaign           Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    CreateCampaign           -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteSolution           -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateSolution           -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitSolutionVersion      -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    WaitSolutionVersion      Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Function    DeleteSolution           Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    DeleteSolution           -
# CREATE_COMPLETE          AWS::Lambda::Function    WaitSolutionVersion      -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    CreateSolution           Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    CreateSolution           -
# CREATE_IN_PROGRESS       AWS::StepFunctions::St   DeleteAllDatasetGroupR   -
#                          ateMachine               esources
# CREATE_COMPLETE          AWS::IAM::Role           AttachEventTrackerRole   -
# CREATE_COMPLETE          AWS::IAM::Role           ImportDataRole           -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ImportData               -
# CREATE_IN_PROGRESS       AWS::StepFunctions::St   DeleteAllDatasetGroupR   Resource creation
#                          ateMachine               esources                 Initiated
# CREATE_COMPLETE          AWS::StepFunctions::St   DeleteAllDatasetGroupR   -
#                          ateMachine               esources
# CREATE_IN_PROGRESS       AWS::Lambda::Function    AttachEventTracker       -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    ImportData               Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    ImportData               -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    AttachEventTracker       Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    AttachEventTracker       -
# CREATE_IN_PROGRESS       AWS::StepFunctions::St   DeployStateMachine       -
#                          ateMachine
# CREATE_IN_PROGRESS       AWS::StepFunctions::St   DeployStateMachine       Resource creation
#                          ateMachine                                        Initiated
# CREATE_COMPLETE          AWS::StepFunctions::St   DeployStateMachine       -
#                          ateMachine
# CREATE_IN_PROGRESS       AWS::Lambda::Function    S3Lambda                 -
# CREATE_IN_PROGRESS       AWS::Lambda::Function    S3Lambda                 Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::Lambda::Function    S3Lambda                 -
# CREATE_IN_PROGRESS       AWS::Lambda::Permissio   S3LambdaS3BucketPermis   Resource creation
#                          n                        sion                     Initiated
# CREATE_IN_PROGRESS       AWS::Lambda::Permissio   S3LambdaS3BucketPermis   -
#                          n                        sion
# CREATE_COMPLETE          AWS::Lambda::Permissio   S3LambdaS3BucketPermis   -
#                          n                        sion
# CREATE_IN_PROGRESS       AWS::S3::Bucket          InputBucket              Resource creation
#                                                                            Initiated
# CREATE_IN_PROGRESS       AWS::S3::Bucket          InputBucket              -
# CREATE_COMPLETE          AWS::S3::Bucket          InputBucket              -
# CREATE_IN_PROGRESS       AWS::S3::BucketPolicy    PersonalizeS3Policy      -
# CREATE_COMPLETE          AWS::S3::BucketPolicy    PersonalizeS3Policy      -
# CREATE_IN_PROGRESS       AWS::S3::BucketPolicy    PersonalizeS3Policy      Resource creation
#                                                                            Initiated
# CREATE_COMPLETE          AWS::CloudFormation::S   notebook-automation      -
#                          tack
# -------------------------------------------------------------------------------------------------
#
# CloudFormation outputs from deployed stack
# -------------------------------------------------------------------------------------------------
# Outputs
# -------------------------------------------------------------------------------------------------
# Key                 InputBucketName
# Description         The S3 bucket name
# Value               notebook-automation-inputbucket-afxmbuzu2h16
#
# Key                 DeployStateMachineArn
# Description         The Create StateMachine Arn
# Value               arn:aws:states:us-east-1:144386903708:stateMachine:DeployStateMachine-
# ziwRPITE9azo
# -------------------------------------------------------------------------------------------------
#
# Successfully created/updated stack - notebook-automation in us-east-1

# %% [markdown]
# ## Uploading data

# %% [markdown]
# Let's get the bucket that our cloudformation deployed. We will be uploading our data to this bucket, plus the configuration file to trigger the automation

# %%
bucket = !aws cloudformation describe-stacks --stack-name notebook-automation --query "Stacks[0].Outputs[?OutputKey=='InputBucketName'].OutputValue" --output text
bucket_name = bucket[0]
print(bucket_name)
# Out:
# notebook-automation-inputbucket-afxmbuzu2h16

# %% [markdown]
# Now that we have the bucket name, lets copy over our Media data so we can explore and upload to S3

# %%
# !cp -R /home/ec2-user/SageMaker/amazon-personalize-immersion-day/automation/ml_ops/domain/Media ./example

# %%
# Import Dependencies

import boto3
import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
import requests
import csv
import sys
import botocore
import uuid
from collections import defaultdict
import random
import numpy as np

from packaging import version
from botocore.exceptions import ClientError
from pathlib import Path

# %matplotlib inline

# Setup Clients

personalize = boto3.client('personalize')
personalize_runtime = boto3.client('personalize-runtime')
personalize_events = boto3.client('personalize-events')

# We will upload our training data in these files:
raw_items_filename = "example/data/Items/items.csv"                # Do Not Change
raw_users_filename = "example/data/Users/users.csv"                # Do Not Change
raw_interactions_filename = "example/data/Interactions/interactions.csv"  # Do Not Change
items_filename = "items.csv"                # Do Not Change
users_filename = "users.csv"                # Do Not Change
interactions_filename = "interactions.csv"  # Do Not Change

# %%
interactions_df = pd.read_csv(raw_interactions_filename)
interactions_df.head()
# Out:
#    USER_ID  ITEM_ID  TIMESTAMP EVENT_TYPE
# 0      429      222  828124615      watch
# 1      429      227  828124615      click
# 2      429      595  828124615      watch
# 3      429      592  828124615      watch
# 4      429      590  828124615      watch

# %% [markdown]
# There are 2 ways of uploading your datasets to S3:
# 1. Using the boto3 SDK
# 1. Using the CLI
#
# In this example we are going to use the CLI command

# %%
# !aws s3 sync ./example/data s3://$bucket_name
# Out:
# upload: example/data/Items/item-meta.csv to s3://notebook-automation-inputbucket-afxmbuzu2h16/Items/item-meta.csv
# upload: example/data/Interactions/interactions.csv to s3://notebook-automation-inputbucket-afxmbuzu2h16/Interactions/interactions.csv

# %% [markdown]
# ## Starting the State Machine Execution

# %% [markdown]
# In order to execute the MLOps pipeline we need to provide a parameters file that will tell our state machine which names and configurations we want in our Amazon Personalize deployment.
#
# We have prepared a parameters.json file, let's explore it

# %%
with open('example/params.json') as f:
  data = json.load(f)

print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "campaigns": {
#         "personalizedRankingCampaign": {
#             "minProvisionedTPS": 1,
#             "name": "personalizedRankingCampaign"
#         },
#         "simsCampaign": {
#             "minProvisionedTPS": 1,
#             "name": "simsCampaign"
#         },
#         "userPersonalizationCampaign": {
#             "minProvisionedTPS": 1,
#             "name": "userPersonalizationCampaign"
#         }
#     },
#     "datasetGroup": {
#         "name": "AmazonPersonalizeImmersionDay"
#     },
#     "datasets": {
#         "Interactions": {
#             "name": "InteractionsDataset",
#             "schema": {
#                 "fields": [
#                     {
#                         "name": "USER_ID",
#                         "type": "string"
#                     },
#                     {
#                         "name": "ITEM_ID",
#                         "type": "string"
#                     },
#                     {
#                         "name": "EVENT_TYPE",
#                         "type": "string"
#                     },
#                     {
#                         "name": "TIMESTAMP",
#                         "type": "long"
#                     }
#                 ],
#                 "name": "Interactions",
#                 "namespace": "com.amazonaws.personalize.schema",
#                 "type": "record",
#                 "version": "1.0"
#             }
#         },
#         "Items": {
#             "name": "ItemsDataset",
#             "schema": {
#                 "fields": [
#                     {
#                         "name": "ITEM_ID",
#                         "type": "string"
#                     },
#                     {
#                         "categorical": true,
#                         "name": "GENRE",
#                         "type": "string"
#                     },
#                     {
#                         "name": "YEAR",
#                         "type": "int"
#                     }
#                 ],
#                 "name": "Items",
#                 "namespace": "com.amazonaws.personalize.schema",
#                 "type": "record",
#                 "version": "1.0"
#             }
#         }
#     },
#     "eventTracker": {
#         "name": "AmazonPersonalizeImmersionDayEventTracker"
#     },
#     "solutions": {
#         "personalizedRanking": {
#             "name": "personalizedRankingSolution",
#             "recipeArn": "arn:aws:personalize:::recipe/aws-personalized-ranking"
#         },
#         "sims": {
#             "name": "simsSolution",
#             "recipeArn": "arn:aws:personalize:::recipe/aws-sims"
#         },
#         "userPersonalization": {
#             "name": "userPersonalizationSolution",
#             "recipeArn": "arn:aws:personalize:::recipe/aws-user-personalization"
#         }
#     }
# }

# %% [markdown]
# This parameters file is set up to run at the beginning of this workshop. So let's modify a couple fields to make sure we are not overwritting our previous deployment

# %%
# Dataset Groups
data['datasetGroup']['name'] = 'notebook-automation'
 
# Datasets 
data['datasets']['Interactions']['name'] = 'na-interactions-ds'
data['datasets']['Items']['name'] = 'na-items-ds'

# Solutions

data['solutions']['personalizedRanking']['name'] = 'na-personalizedRankingCampaign'
data['solutions']['sims']['name'] = 'na-simsCampaign'
data['solutions']['userPersonalization']['name'] = 'na-userPersonalizationCampaign'

# Campaigns

data['campaigns']['personalizedRankingCampaign']['name'] = 'na-personalizedRankingCampaign'
data['campaigns']['simsCampaign']['name'] = 'na-simsCampaign'
data['campaigns']['userPersonalizationCampaign']['name'] = 'na-userPersonalizationCampaign'

# Event Tracker

data['eventTracker']['name'] = 'na-eventTracker'

print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "campaigns": {
#         "personalizedRankingCampaign": {
#             "minProvisionedTPS": 1,
#             "name": "na-personalizedRankingCampaign"
#         },
#         "simsCampaign": {
#             "minProvisionedTPS": 1,
#             "name": "na-simsCampaign"
#         },
#         "userPersonalizationCampaign": {
#             "minProvisionedTPS": 1,
#             "name": "na-userPersonalizationCampaign"
#         }
#     },
#     "datasetGroup": {
#         "name": "notebook-automation"
#     },
#     "datasets": {
#         "Interactions": {
#             "name": "na-interactions-ds",
#             "schema": {
#                 "fields": [
#                     {
#                         "name": "USER_ID",
#                         "type": "string"
#                     },
#                     {
#                         "name": "ITEM_ID",
#                         "type": "string"
#                     },
#                     {
#                         "name": "EVENT_TYPE",
#                         "type": "string"
#                     },
#                     {
#                         "name": "TIMESTAMP",
#                         "type": "long"
#                     }
#                 ],
#                 "name": "Interactions",
#                 "namespace": "com.amazonaws.personalize.schema",
#                 "type": "record",
#                 "version": "1.0"
#             }
#         },
#         "Items": {
#             "name": "na-items-ds",
#             "schema": {
#                 "fields": [
#                     {
#                         "name": "ITEM_ID",
#                         "type": "string"
#                     },
#                     {
#                         "categorical": true,
#                         "name": "GENRE",
#                         "type": "string"
#                     },
#                     {
#                         "name": "YEAR",
#                         "type": "int"
#                     }
#                 ],
#                 "name": "Items",
#                 "namespace": "com.amazonaws.personalize.schema",
#                 "type": "record",
#                 "version": "1.0"
#             }
#         }
#     },
#     "eventTracker": {
#         "name": "na-eventTracker"
#     },
#     "solutions": {
#         "personalizedRanking": {
#             "name": "na-personalizedRankingCampaign",
#             "recipeArn": "arn:aws:personalize:::recipe/aws-personalized-ranking"
#         },
#         "sims": {
#             "name": "na-simsCampaign",
#             "recipeArn": "arn:aws:personalize:::recipe/aws-sims"
#         },
#         "userPersonalization": {
#             "name": "na-userPersonalizationCampaign",
#             "recipeArn": "arn:aws:personalize:::recipe/aws-user-personalization"
#         }
#     }
# }

# %% [markdown]
# ## Updating and uploading your parameters file to S3

# %% [markdown]
# First let's write the file locally

# %%
with open('example/params.json', 'w') as outfile:
    json.dump(data, outfile)

# %% [markdown]
# Now we can upload this file to S3, we are going to be using the CLI to do so

# %%
# !aws s3 cp ./example/params.json s3://$bucket_name
# Out:
# upload: example/params.json to s3://notebook-automation-inputbucket-afxmbuzu2h16/params.json

# %% [markdown]
# ## Validating the deployment
#
# So far we have deployed the automation required lets take a look at the stepfunctions execution.

# %%
client = boto3.client('stepfunctions')
stateMachineArn = !aws cloudformation describe-stacks --stack-name notebook-automation --query "Stacks[0].Outputs[?OutputKey=='DeployStateMachineArn'].OutputValue" --output text
stateMachineArn= stateMachineArn[0]

# %%
describe_response = client.describe_state_machine(
    stateMachineArn=stateMachineArn
)
print(json.dumps(describe_response, indent=4, sort_keys=True, default=str))

# %%
executions_response = client.list_executions(
    stateMachineArn=stateMachineArn,
    statusFilter='RUNNING',
    maxResults=2
)
print(json.dumps(executions_response, indent=4, sort_keys=True, default=str))
# Out:
# {
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "345",
#             "content-type": "application/x-amz-json-1.0",
#             "x-amzn-requestid": "79e283e2-9f15-47aa-924e-8f7cf3ebe70c"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "79e283e2-9f15-47aa-924e-8f7cf3ebe70c",
#         "RetryAttempts": 0
#     },
#     "executions": [
#         {
#             "executionArn": "arn:aws:states:us-east-1:144386903708:execution:DeployStateMachine-ziwRPITE9azo:2021_03_05_19_53_36",
#             "name": "2021_03_05_19_53_36",
#             "startDate": "2021-03-05 19:53:37.123000+00:00",
#             "stateMachineArn": "arn:aws:states:us-east-1:144386903708:stateMachine:DeployStateMachine-ziwRPITE9azo",
#             "status": "SUCCEEDED",
#             "stopDate": "2021-03-05 21:32:27.027000+00:00"
#         }
#     ]
# }

# %%
while (True):
    if (executions_response['executions'][0]['status'] == 'SUCCEEDED'):
        break
    else:
        print (json.dumps(executions_response['executions'][0], indent=4, sort_keys=True, default=str))
        time.sleep(60)
# Out:
# {
#     "executionArn": "arn:aws:states:us-east-1:674465894274:execution:DeployStateMachine-DOVbLib1H3Qs:2021_03_14_19_03_08",
#     "name": "2021_03_14_19_03_08",
#     "startDate": "2021-03-14 19:03:09.703000+00:00",
#     "stateMachineArn": "arn:aws:states:us-east-1:674465894274:stateMachine:DeployStateMachine-DOVbLib1H3Qs",
#     "status": "RUNNING"
# }

# %% [markdown]
# ### Let's look at the succeeded execution
#
# Once your step functions are done executing, you can list the executions and describe them

# %%
executions_response = client.list_executions(
    stateMachineArn=stateMachineArn,
    statusFilter='SUCCEEDED',
    maxResults=2
)
print(json.dumps(executions_response, indent=4, sort_keys=True, default=str))
# Out:
# {
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "345",
#             "content-type": "application/x-amz-json-1.0",
#             "x-amzn-requestid": "8a8a77c9-9378-4783-a310-a5509997bcff"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "8a8a77c9-9378-4783-a310-a5509997bcff",
#         "RetryAttempts": 0
#     },
#     "executions": [
#         {
#             "executionArn": "arn:aws:states:us-east-1:144386903708:execution:DeployStateMachine-ziwRPITE9azo:2021_03_05_19_53_36",
#             "name": "2021_03_05_19_53_36",
#             "startDate": "2021-03-05 19:53:37.123000+00:00",
#             "stateMachineArn": "arn:aws:states:us-east-1:144386903708:stateMachine:DeployStateMachine-ziwRPITE9azo",
#             "status": "SUCCEEDED",
#             "stopDate": "2021-03-05 21:32:27.027000+00:00"
#         }
#     ]
# }

# %%
describe_executions_response = client.describe_execution(
    executionArn=executions_response['executions'][0]['executionArn']
)
print(json.dumps(describe_executions_response, indent=4, sort_keys=True, default=str))
# Out:
# {
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "2648",
#             "content-type": "application/x-amz-json-1.0",
#             "x-amzn-requestid": "65b34b45-89cb-4369-9419-f30b91be647b"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "65b34b45-89cb-4369-9419-f30b91be647b",
#         "RetryAttempts": 0
#     },
#     "executionArn": "arn:aws:states:us-east-1:144386903708:execution:DeployStateMachine-ziwRPITE9azo:2021_03_05_19_53_36",
#     "input": "{\"bucket\": \"notebook-automation-inputbucket-afxmbuzu2h16\", \"currentDate\": \"2021_03_05_19_53_36\", \"params\": {\"datasetGroup\": {\"name\": \"notebook-automation\"}, \"datasets\": {\"Interactions\": {\"name\": \"na-interactions-ds\", \"schema\": {\"type\": \"record\", \"name\": \"Interactions\", \"namespace\": \"com.amazonaws.personalize.schema\", \"fields\": [{\"name\": \"USER_ID\", \"type\": \"string\"}, {\"name\": \"ITEM_ID\", \"type\": \"string\"}, {\"name\": \"EVENT_TYPE\", \"type\": \"string\"}, {\"name\": \"TIMESTAMP\", \"type\": \"long\"}], \"version\": \"1.0\"}}, \"Items\": {\"name\": \"na-items-ds\", \"schema\": {\"type\": \"record\", \"name\": \"Items\", \"namespace\": \"com.amazonaws.personalize.schema\", \"fields\": [{\"name\": \"ITEM_ID\", \"type\": \"string\"}, {\"name\": \"CATEGORY\", \"type\": \"string\", \"categorical\": true}, {\"name\": \"STYLE\", \"type\": \"string\", \"categorical\": true}], \"version\": \"1.0\"}}, \"Users\": {\"name\": \"na-users-ds\", \"schema\": {\"type\": \"record\", \"name\": \"Users\", \"namespace\": \"com.amazonaws.personalize.schema\", \"fields\": [{\"name\": \"USER_ID\", \"type\": \"string\"}, {\"name\": \"AGE\", \"type\": \"int\"}, {\"name\": \"GENDER\", \"type\": \"string\", \"categorical\": true}], \"version\": \"1.0\"}}}, \"solutions\": {\"userPersonalization\": {\"name\": \"na-userPersonalizationCampaign\", \"recipeArn\": \"arn:aws:personalize:::recipe/aws-user-personalization\"}, \"sims\": {\"name\": \"na-simsCampaign\", \"recipeArn\": \"arn:aws:personalize:::recipe/aws-sims\"}, \"personalizedRanking\": {\"name\": \"na-personalizedRankingCampaign\", \"recipeArn\": \"arn:aws:personalize:::recipe/aws-personalized-ranking\"}}, \"eventTracker\": {\"name\": \"na-eventTracker\"}, \"campaigns\": {\"userPersonalizationCampaign\": {\"name\": \"na-userPersonalizationCampaign\", \"minProvisionedTPS\": 1}, \"simsCampaign\": {\"name\": \"na-simsCampaign\", \"minProvisionedTPS\": 1}, \"personalizedRankingCampaign\": {\"name\": \"na-personalizedRankingCampaign\", \"minProvisionedTPS\": 1}}}}",
#     "inputDetails": {
#         "included": true
#     },
#     "name": "2021_03_05_19_53_36",
#     "output": "true",
#     "outputDetails": {
#         "included": true
#     },
#     "startDate": "2021-03-05 19:53:37.123000+00:00",
#     "stateMachineArn": "arn:aws:states:us-east-1:144386903708:stateMachine:DeployStateMachine-ziwRPITE9azo",
#     "status": "SUCCEEDED",
#     "stopDate": "2021-03-05 21:32:27.027000+00:00"
# }

# %% [markdown]
# ### Let's look at the input that was delivered to the State Machine

# %% [markdown]
# As we can see below, this is the input from our Parameters file we uploaded to S3. This input json was then passed to lambda functions in the state machine to utilize across Amazon Personalize APIs

# %%
print(json.dumps(json.loads(describe_executions_response['input']), indent=4, sort_keys=True, default=str))
# Out:
# {
#     "bucket": "notebook-automation-inputbucket-afxmbuzu2h16",
#     "currentDate": "2021_03_05_19_53_36",
#     "params": {
#         "campaigns": {
#             "personalizedRankingCampaign": {
#                 "minProvisionedTPS": 1,
#                 "name": "na-personalizedRankingCampaign"
#             },
#             "simsCampaign": {
#                 "minProvisionedTPS": 1,
#                 "name": "na-simsCampaign"
#             },
#             "userPersonalizationCampaign": {
#                 "minProvisionedTPS": 1,
#                 "name": "na-userPersonalizationCampaign"
#             }
#         },
#         "datasetGroup": {
#             "name": "notebook-automation"
#         },
#         "datasets": {
#             "Interactions": {
#                 "name": "na-interactions-ds",
#                 "schema": {
#                     "fields": [
#                         {
#                             "name": "USER_ID",
#                             "type": "string"
#                         },
#                         {
#                             "name": "ITEM_ID",
#                             "type": "string"
#                         },
#                         {
#                             "name": "EVENT_TYPE",
#                             "type": "string"
#                         },
#                         {
#                             "name": "TIMESTAMP",
#                             "type": "long"
#                         }
#                     ],
#                     "name": "Interactions",
#                     "namespace": "com.amazonaws.personalize.schema",
#                     "type": "record",
#                     "version": "1.0"
#                 }
#             },
#             "Items": {
#                 "name": "na-items-ds",
#                 "schema": {
#                     "fields": [
#                         {
#                             "name": "ITEM_ID",
#                             "type": "string"
#                         },
#                         {
#                             "categorical": true,
#                             "name": "CATEGORY",
#                             "type": "string"
#                         },
#                         {
#                             "categorical": true,
#                             "name": "STYLE",
#                             "type": "string"
#                         }
#                     ],
#                     "name": "Items",
#                     "namespace": "com.amazonaws.personalize.schema",
#                     "type": "record",
#                     "version": "1.0"
#                 }
#             },
#             "Users": {
#                 "name": "na-users-ds",
#                 "schema": {
#                     "fields": [
#                         {
#                             "name": "USER_ID",
#                             "type": "string"
#                         },
#                         {
#                             "name": "AGE",
#                             "type": "int"
#                         },
#                         {
#                             "categorical": true,
#                             "name": "GENDER",
#                             "type": "string"
#                         }
#                     ],
#                     "name": "Users",
#                     "namespace": "com.amazonaws.personalize.schema",
#                     "type": "record",
#                     "version": "1.0"
#                 }
#             }
#         },
#         "eventTracker": {
#             "name": "na-eventTracker"
#         },
#         "solutions": {
#             "personalizedRanking": {
#                 "name": "na-personalizedRankingCampaign",
#                 "recipeArn": "arn:aws:personalize:::recipe/aws-personalized-ranking"
#             },
#             "sims": {
#                 "name": "na-simsCampaign",
#                 "recipeArn": "arn:aws:personalize:::recipe/aws-sims"
#             },
#             "userPersonalization": {
#                 "name": "na-userPersonalizationCampaign",
#                 "recipeArn": "arn:aws:personalize:::recipe/aws-user-personalization"
#             }
#         }
#     }
# }

# %% [markdown]
# ### Let's look at the time stamps

# %% [markdown]
# As we can see below, this is the input from our Parameters file we uploaded to S3. This input json was then passed to lambda functions in the state machine to utilize across Amazon Personalize APIs

# %%
print("Start Date:")
print(json.dumps(describe_executions_response['startDate'], indent=4, sort_keys=True, default=str))
print("Stop Date:")
print(json.dumps(describe_executions_response['stopDate'], indent=4, sort_keys=True, default=str))
print("Elapsed Time: ")
elapsed_time = describe_executions_response['stopDate'] - describe_executions_response['startDate']
print(elapsed_time)
# Out:
# Start Date:
# "2021-03-05 19:53:37.123000+00:00"
# Stop Date:
# "2021-03-05 21:32:27.027000+00:00"
# Elapsed Time:
# 1:38:49.904000

# %% [markdown]
# As we see above, the automation around an hour with fourty minutes.
#
# If you are interested in deploying this example in your environment, visit our [Github Samples Page](https://github.com/aws-samples/amazon-personalize-samples/tree/master/next_steps/operations/ml_ops) to download the latest codebase.
